# %% [markdown]
# # Neural Network

# %% [markdown]
# Data:
# $f(x) = (x^3) +(3x^2)-2$<br>
#
#
#
# The Alrorightm itself consists of three components:
# 1.  Hypothesis: $h_w(x) = U_kz_k + c_k$
# 2.  Loss: $\frac{1}{N}\sum_{i=1}^n(y_i-\hat{y}_i)^2$
#
# 3.  Optimization: <br>
# $ \substack{minimize\\w} J(w) = \frac{1}{m}\sum_{i=1}^m l[h_w(x_i),y_i)]$<br>
# $w \leftarrow -\alpha\Delta J(w)$
#
#
# Neural Network:<br>
# $h_w(x) = U_2\sigma(U_1x+b_1)+b_2$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
def generate_training_points(n):
    training_points = []
    f = lambda x: (x**3)+(3*x**2)-(2)
    
    for s in np.linspace(-3,2,n):
        training_points.append([s,f(s)])
        
    return np.array(training_points)

# %%
data = generate_training_points(1000)

X = data[:,0]
Y_hat = data[:,1]
N = len(data)


plt.plot(data[:,0],data[:,1])

# %% [markdown]
# ## Network

# %%
U_1 = np.random.normal(size=(50,1))
b_1 = np.zeros((50,1))

U_2 = np.random.normal(size=(1,50))
b_2 = np.zeros((1,1))

# %%
def sigmoid(x):
    return np.exp(x) / (np.exp(x) +1)

def derivative_sigmoid(x):
    return sigmoid(x)*(1-sigmoid(x))

def relu(x):
    return np.maximum(x,0)

def derivative_relu(x):
    return np.greater(x, 0.).astype(np.float32)

def SE(y, y_hat):
    return np.square(y-y_hat)

# %%
def feed_forward(x,U_1,b_1,U_2,b_2):
    z1 = U_1.dot(x)+b_1
    a1 = relu(z1)
    
    z2 = U_2.dot(a1)+b_2
    # No activation function since we use it for regression.
    return z2

def backprop(x,U_1,b_1,U_2,b_2,y_hat,alpha):
    
    z1 = U_1.dot(x)+b_1
    a1 = relu(z1)
    
    z2 = U_2.dot(a1)+b_2
    # No activation function since we use it for regression.
    
 ############### BACKPROP ################

    dl_dyhat = 2*(z2-y_hat)
    
    dl_dd = dl_dyhat
    dl_db2 = dl_dyhat
    
    dl_dphi = U_2*dl_dd
    dl_dU2 = a1*dl_dd
    
    dl_dp = derivative_relu(z1)*dl_dphi.T
    
    dl_dm = dl_dp
    dl_db1 = dl_dp
    
    dl_dU1 = dl_dm*x

    
    U_1 -= alpha*dl_dU1
    b_1 -= alpha*dl_db1
    U_2 -= alpha*dl_dU2.T
    b_2 -= alpha*dl_db2
    

    
    return (U_1,b_1,U_2,b_2)

# %%
def train(U_1,b_1,U_2,b_2,X,Y_hat,N,epochs = 100, alpha = 1e-4):
    loss = []
    acc = []
    for e in range(epochs):
        l = []
        for i in range(len(X)):
            y = feed_forward(X[i],U_1,b_1,U_2,b_2)
            l.append(SE(y,Y_hat[i]))
            U_1,b_1,U_2,b_2 = backprop(X[i],U_1,b_1,U_2,b_2,Y_hat[i],alpha)
        loss.append(sum(l)/len(X))   
        print(f"Epoch: {e+1}, loss = {sum(l)/len(X)}")
    return (U_1, b_1, U_2, b_2,np.array(loss).reshape(-2))

# %%
epochs = 100
alpha = 1e-4
r = train(U_1,b_1,U_2,b_2,X,Y_hat,N,epochs=epochs,alpha=alpha)
# Out:
# Epoch: 1, loss = [[1.84250827]]
# Epoch: 2, loss = [[2.38944126]]
# Epoch: 3, loss = [[1.59964116]]
# Epoch: 4, loss = [[1.23026159]]
# Epoch: 5, loss = [[1.06511483]]
# Epoch: 6, loss = [[0.99885856]]
# Epoch: 7, loss = [[0.97029259]]
# Epoch: 8, loss = [[0.92912491]]
# Epoch: 9, loss = [[0.87795319]]
# Epoch: 10, loss = [[0.82833492]]
# Epoch: 11, loss = [[0.78467726]]
# Epoch: 12, loss = [[0.74717663]]
# Epoch: 13, loss = [[0.71471345]]
# Epoch: 14, loss = [[0.68627036]]
# Epoch: 15, loss = [[0.66020061]]
# Epoch: 16, loss = [[0.63586521]]
# Epoch: 17, loss = [[0.61255935]]
# Epoch: 18, loss = [[0.59040845]]
# Epoch: 19, loss = [[0.56971554]]
# Epoch: 20, loss = [[0.5512114]]
# Epoch: 21, loss = [[0.53402101]]
# Epoch: 22, loss = [[0.51840885]]
# Epoch: 23, loss = [[0.50346588]]
# Epoch: 24, loss = [[0.48925789]]
# Epoch: 25, loss = [[0.47591031]]
# Epoch: 26, loss = [[0.46360636]]
# Epoch: 27, loss = [[0.45239115]]
# Epoch: 28, loss = [[0.44220111]]
# Epoch: 29, loss = [[0.43305701]]
# Epoch: 30, loss = [[0.42463064]]
# Epoch: 31, loss = [[0.41657806]]
# Epoch: 32, loss = [[0.40857186]]
# Epoch: 33, loss = [[0.40078929]]
# Epoch: 34, loss = [[0.39331948]]
# Epoch: 35, loss = [[0.38600725]]
# Epoch: 36, loss = [[0.37929551]]
# Epoch: 37, loss = [[0.37299659]]
# Epoch: 38, loss = [[0.36738919]]
# Epoch: 39, loss = [[0.36179708]]
# Epoch: 40, loss = [[0.35661808]]
# Epoch: 41, loss = [[0.35212847]]
# Epoch: 42, loss = [[0.348023]]
# Epoch: 43, loss = [[0.34391771]]
# Epoch: 44, loss = [[0.34016526]]
# Epoch: 45, loss = [[0.33667253]]
# Epoch: 46, loss = [[0.33349947]]
# Epoch: 47, loss = [[0.33043415]]
# Epoch: 48, loss = [[0.32753299]]
# Epoch: 49, loss = [[0.32475593]]
# Epoch: 50, loss = [[0.32219714]]
# Epoch: 51, loss = [[0.3199207]]
# Epoch: 52, loss = [[0.31748703]]
# Epoch: 53, loss = [[0.31510462]]
# Epoch: 54, loss = [[0.31298728]]
# Epoch: 55, loss = [[0.31116762]]
# Epoch: 56, loss = [[0.30914049]]
# Epoch: 57, loss = [[0.30711273]]
# Epoch: 58, loss = [[0.30523031]]
# Epoch: 59, loss = [[0.30376673]]
# Epoch: 60, loss = [[0.3019418]]
# Epoch: 61, loss = [[0.30028515]]
# Epoch: 62, loss = [[0.29894161]]
# Epoch: 63, loss = [[0.29729427]]
# Epoch: 64, loss = [[0.29601327]]
# Epoch: 65, loss = [[0.29444752]]
# Epoch: 66, loss = [[0.29294084]]
# Epoch: 67, loss = [[0.2919214]]
# Epoch: 68, loss = [[0.2905116]]
# Epoch: 69, loss = [[0.28937766]]
# Epoch: 70, loss = [[0.28797242]]
# Epoch: 71, loss = [[0.28694733]]
# Epoch: 72, loss = [[0.28568365]]
# Epoch: 73, loss = [[0.28463625]]
# Epoch: 74, loss = [[0.2833734]]
# Epoch: 75, loss = [[0.28250268]]
# Epoch: 76, loss = [[0.28155721]]
# Epoch: 77, loss = [[0.2803143]]
# Epoch: 78, loss = [[0.27941607]]
# Epoch: 79, loss = [[0.27838254]]
# Epoch: 80, loss = [[0.27758885]]
# Epoch: 81, loss = [[0.27673209]]
# Epoch: 82, loss = [[0.27555749]]
# Epoch: 83, loss = [[0.27471078]]
# Epoch: 84, loss = [[0.27382377]]
# Epoch: 85, loss = [[0.27295815]]
# Epoch: 86, loss = [[0.2720299]]
# Epoch: 87, loss = [[0.27128965]]
# Epoch: 88, loss = [[0.27048101]]
# Epoch: 89, loss = [[0.26958554]]
# Epoch: 90, loss = [[0.26855118]]
# Epoch: 91, loss = [[0.26793827]]
# Epoch: 92, loss = [[0.26725444]]
# Epoch: 93, loss = [[0.26647708]]
# Epoch: 94, loss = [[0.26568511]]
# Epoch: 95, loss = [[0.26486631]]
# Epoch: 96, loss = [[0.26407194]]
# Epoch: 97, loss = [[0.26322831]]
# Epoch: 98, loss = [[0.2623495]]
# Epoch: 99, loss = [[0.26167141]]
# Epoch: 100, loss = [[0.26095535]]

# %%
pred = []
for x in X:
    pred.append(feed_forward(x,r[0],r[1],r[2],r[3]).reshape(1))
print(f"Loss (MSE): {r[-1][-1]}")
# Out:
# Loss (MSE): 0.26095535271134024

# %%
plt.plot(X,pred,X,Y_hat)
plt.legend(["Prediction","Ground Truth"])

# %%
plt.plot(range(1,epochs+1),r[-1])
plt.legend(["Loss"])
